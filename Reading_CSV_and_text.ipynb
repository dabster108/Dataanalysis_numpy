# %% [markdown]
# <a href="https://colab.research.google.com/github/dabster108/Dataanalysis_numpy/blob/main/Reading_CSV_and_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filepath = '/content/sample_data/btc-market-price.csv'

with open(filepath, 'r') as reader:
    print(reader)
# Out:
# <_io.TextIOWrapper name='/content/sample_data/btc-market-price.csv' mode='r' encoding='UTF-8'>

# %%
filepath = '/content/sample_data/btc-market-price.csv'

with open(filepath, 'r') as reader:
    for index, line in enumerate(reader.readlines()):
        # read just the first 10 lines
        if (index < 10):
            print(index, line)
# Out:
# 0 2/4/17 0:00,1099.169125
#
# 1 3/4/17 0:00,1141.813
#
# 2 4/4/17 0:00,?
#
# 3 5/4/17 0:00,1133.079314
#
# 4 6/4/17 0:00,-
#
# 5 7/4/17 0:00,-
#
# 6 8/4/17 0:00,1181.149838
#
# 7 9/4/17 0:00,1208.8005
#
# 8 10/4/17 0:00,1207.744875
#
# 9 11/4/17 0:00,1226.617038

# %%
import pandas as pd
csv_url = "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"

pd.read_csv(csv_url).head()
# Out:
#   Country Name Country Code  Year         Value
# 0  Afghanistan          AFG  2000  3.521418e+09
# 1  Afghanistan          AFG  2001  2.813572e+09
# 2  Afghanistan          AFG  2002  3.825701e+09
# 3  Afghanistan          AFG  2003  4.520947e+09
# 4  Afghanistan          AFG  2004  5.224897e+09

# %%
df = pd.read_csv('/content/sample_data/btc-market-price.csv')

df.head()
# df stores the DataFrame containing the CSV data.

''' head() displays the first 5 rows (by default) of the dataset. '''
# Out:
# ' head() displays the first 5 rows (by default) of the dataset. '

# %%
df = pd.read_csv('/content/sample_data/btc-market-price.csv')

df.head()
# Out:
#    2/4/17 0:00  1099.169125
# 0  3/4/17 0:00     1141.813
# 1  4/4/17 0:00            ?
# 2  5/4/17 0:00  1133.079314
# 3  6/4/17 0:00            -
# 4  7/4/17 0:00            -

# %%
df = pd.read_csv('/content/sample_data/btc-market-price.csv',
                 header=None)

# %%
df = pd.read_csv('/content/sample_data/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'])
df.head() # we can determine the null values
# Out:
#              0            1
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df = pd.read_csv('/content/sample_data/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype= {'Price' : 'float'})
df.head()
print(df.dtypes)
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
#Date parser using parse_dates paramete
df = pd.read_csv('/content/sample_data/btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0])
df.head()
# automatically converts the timestamps to string
# Out:
# <ipython-input-17-b152ae373008>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('/content/sample_data/btc-market-price.csv',
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
import pandas as pd
exam_pd = pd.read_csv('/content/sample_data/exam_review.csv')
exam_pd
# Out:
#                                first_name>last_name>age>math_score>french_score
# Ray>Morley>18>"68     000">"75                                             000"
# Melvin>Scott>24>77>83 NaN                                                   NaN
# Amirah>Haley>22>92>67 NaN                                                   NaN
# Gerard>Mills>19>"78   000">72                                               NaN
# Amy>Grimes>23>91>81   NaN                                                   NaN

# %%
# using the seperator
exam_pd = pd.read_csv('/content/sample_data/exam_review.csv',
                      sep='>')
exam_pd
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
exam_pd = pd.read_csv('/content/sample_data/exam_review.csv',
                      sep='>')
exam_pd[['math_score', 'french_score']].dtypes
# Out:
# math_score      object
# french_score    object
# dtype: object

# %%
import pandas as pd

# Read the CSV with correct decimal and separator settings
exam_pd = pd.read_csv('/content/sample_data/exam_review.csv',
                       sep='>', decimal=',')

# Check data types of specific columns
print(exam_pd[['math_score', 'french_score']].dtypes)

# Display DataFrame
print(exam_pd)
# Out:
# math_score      float64
# french_score    float64
# dtype: object
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_pd.dtypes
# Out:
# first_name       object
# last_name        object
# age               int64
# math_score      float64
# french_score    float64
# dtype: object

# %%
#skiprows
pd.read_csv('/content/sample_data/exam_review.csv',
            sep='>',
            skiprows=2)
# Out:
#    Melvin   Scott  24      77  83
# 0  Amirah   Haley  22      92  67
# 1  Gerard   Mills  19  78,000  72
# 2     Amy  Grimes  23      91  81

# %%
pd.read_csv('/content/sample_data/exam_review.csv',
            sep='>',
            skip_blank_lines=True)
# skip_blank_lines : if this set to true then it will not display the blank lines
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
pd.read_csv('/content/sample_data/exam_review.csv',
            usecols=['first_name', 'last_name', 'age'],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
#use cols helps us to know about the or get the column
exam_test_1 = pd.read_csv('/content/sample_data/exam_review.csv',
                          sep='>',
                          usecols=['last_name'])
exam_test_1
# Out:
#   last_name
# 0    Morley
# 1     Scott
# 2     Haley
# 3     Mills
# 4    Grimes

# %%
import pandas as pd

# Read only the 'last_name' column
exam_test_2 = pd.read_csv('/content/sample_data/exam_review.csv',
                          sep='>',
                          usecols=['last_name'])

# Convert DataFrame to Series if needed
exam_test_2 = exam_test_2.squeeze("columns")  # Alternative for squeeze=True

# Display output
print(exam_test_2)
# Out:
# 0    Morley
# 1     Scott
# 2     Haley
# 3     Mills
# 4    Grimes
# Name: last_name, dtype: object

# %%
'''
exam_df.to_csv()
exam_df.to_csv('out.csv')
exam_df.to_csv('out.csv',
               index=None)
pd.read_csv('out.csv')


'''
# Out:
# " \nexam_df.to_csv()\nexam_df.to_csv('out.csv')\nexam_df.to_csv('out.csv',\n               index=None)\npd.read_csv('out.csv')\n\n\n"

# %%
# !pip install sqlalchemy

# %%
#Reading from database

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('/content/chinook.db')

# %%
#Cursors allow us to execute SQL queries against a database:

cur = conn.cursor()

# %%
results = cur.fetchall()
results
# Out:
# []

# %%
# !pip install lxml

# %%
import pandas as pd

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th>
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td>
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td>
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td>
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td>
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""

# %%
dfs = pd.read_html(html_string)
# Out:
# <ipython-input-5-bb5fd531bf31>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_string)
